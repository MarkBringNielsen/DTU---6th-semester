# %%
import pandas as pd
import matplotlib.pyplot as plt

police_data = pd.read_csv("../Police_Department_Incident_Reports__Historical_2003_to_May_2018.csv")

# %%
print(police_data['IncidntNum'].nunique())
print(police_data['Category'].unique())
print(police_data['Category'].value_counts())
# Out:
# 1746914
# ['NON-CRIMINAL' 'ASSAULT' 'SUSPICIOUS OCC' 'OTHER OFFENSES' 'SUICIDE'
#  'VEHICLE THEFT' 'ARSON' 'FRAUD' 'SECONDARY CODES' 'LARCENY/THEFT'
#  'MISSING PERSON' 'BURGLARY' 'WARRANTS' 'DRUG/NARCOTIC' 'VANDALISM'
#  'ROBBERY' 'KIDNAPPING' 'FORGERY/COUNTERFEITING' 'TRESPASS'
#  'DISORDERLY CONDUCT' 'FAMILY OFFENSES' 'DRUNKENNESS' 'WEAPON LAWS'
#  'EMBEZZLEMENT' 'SEX OFFENSES, FORCIBLE' 'RECOVERED VEHICLE'
#  'STOLEN PROPERTY' 'DRIVING UNDER THE INFLUENCE' 'LIQUOR LAWS' 'TREA'
#  'LOITERING' 'BAD CHECKS' 'GAMBLING' 'BRIBERY' 'RUNAWAY' 'PROSTITUTION'
#  'SEX OFFENSES, NON FORCIBLE' 'PORNOGRAPHY/OBSCENE MAT' 'EXTORTION']
# LARCENY/THEFT                  480448
# OTHER OFFENSES                 309358
# NON-CRIMINAL                   238323
# ASSAULT                        194694
# VEHICLE THEFT                  126602
# DRUG/NARCOTIC                  119628
# VANDALISM                      116059
# WARRANTS                       101379
# BURGLARY                        91543
# ...

# %% [markdown]
# Final Excercise

# %%
categories = police_data['Category'].unique()
print(categories)
print(police_data.groupby(by='Category').size())
print(f'There are {len(categories)} categories.')
# Out:
# ['NON-CRIMINAL' 'ASSAULT' 'SUSPICIOUS OCC' 'OTHER OFFENSES' 'SUICIDE'
#  'VEHICLE THEFT' 'ARSON' 'FRAUD' 'SECONDARY CODES' 'LARCENY/THEFT'
#  'MISSING PERSON' 'BURGLARY' 'WARRANTS' 'DRUG/NARCOTIC' 'VANDALISM'
#  'ROBBERY' 'KIDNAPPING' 'FORGERY/COUNTERFEITING' 'TRESPASS'
#  'DISORDERLY CONDUCT' 'FAMILY OFFENSES' 'DRUNKENNESS' 'WEAPON LAWS'
#  'EMBEZZLEMENT' 'SEX OFFENSES, FORCIBLE' 'RECOVERED VEHICLE'
#  'STOLEN PROPERTY' 'DRIVING UNDER THE INFLUENCE' 'LIQUOR LAWS' 'TREA'
#  'LOITERING' 'BAD CHECKS' 'GAMBLING' 'BRIBERY' 'RUNAWAY' 'PROSTITUTION'
#  'SEX OFFENSES, NON FORCIBLE' 'PORNOGRAPHY/OBSCENE MAT' 'EXTORTION']
# Category
# ARSON                            3931
# ASSAULT                        194694
# BAD CHECKS                        925
# BRIBERY                           813
# BURGLARY                        91543
# DISORDERLY CONDUCT              10040
# DRIVING UNDER THE INFLUENCE      5672
# DRUG/NARCOTIC                  119628
# DRUNKENNESS                      9826
# ...

# %%
crimes_by_category = police_data['Category'].value_counts()
print(crimes_by_category)
print(f'Most crimes are {crimes_by_category.max()}')
# Out:
# LARCENY/THEFT                  480448
# OTHER OFFENSES                 309358
# NON-CRIMINAL                   238323
# ASSAULT                        194694
# VEHICLE THEFT                  126602
# DRUG/NARCOTIC                  119628
# VANDALISM                      116059
# WARRANTS                       101379
# BURGLARY                        91543
# SUSPICIOUS OCC                  80444
# MISSING PERSON                  64961
# ROBBERY                         55867
# FRAUD                           41542
# SECONDARY CODES                 25831
# FORGERY/COUNTERFEITING          23050
# WEAPON LAWS                     22234
# TRESPASS                        19449
# PROSTITUTION                    16701
# STOLEN PROPERTY                 11891
# SEX OFFENSES, FORCIBLE          11742
# DISORDERLY CONDUCT              10040
# DRUNKENNESS                      9826
# RECOVERED VEHICLE                8716
# DRIVING UNDER THE INFLUENCE      5672
# KIDNAPPING                       5346
# ...

# %%
plt.figure(figsize=(10,5))
sns.barplot(crimes_by_category.index, crimes_by_category.values, alpha=0.8)
plt.title('Crimes')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Crime', fontsize=12)
plt.show()


chart = police_data['Category'].value_counts().plot(kind='bar', fontsize=8)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90, horizontalalignment='right')
# Out:
# [Text(0, 0, 'LARCENY/THEFT'),
#  Text(0, 0, 'OTHER OFFENSES'),
#  Text(0, 0, 'NON-CRIMINAL'),
#  Text(0, 0, 'ASSAULT'),
#  Text(0, 0, 'VEHICLE THEFT'),
#  Text(0, 0, 'DRUG/NARCOTIC'),
#  Text(0, 0, 'VANDALISM'),
#  Text(0, 0, 'WARRANTS'),
#  Text(0, 0, 'BURGLARY'),
#  Text(0, 0, 'SUSPICIOUS OCC'),
#  Text(0, 0, 'MISSING PERSON'),
#  Text(0, 0, 'ROBBERY'),
#  Text(0, 0, 'FRAUD'),
#  Text(0, 0, 'SECONDARY CODES'),
#  Text(0, 0, 'FORGERY/COUNTERFEITING'),
#  Text(0, 0, 'WEAPON LAWS'),
#  Text(0, 0, 'TRESPASS'),
#  Text(0, 0, 'PROSTITUTION'),
#  Text(0, 0, 'STOLEN PROPERTY'),
#  Text(0, 0, 'SEX OFFENSES, FORCIBLE'),
#  Text(0, 0, 'DISORDERLY CONDUCT'),
#  Text(0, 0, 'DRUNKENNESS'),
#  Text(0, 0, 'RECOVERED VEHICLE'),
#  Text(0, 0, 'DRIVING UNDER THE INFLUENCE'),
#  Text(0, 0, 'KIDNAPPING'),
#  Text(0, 0, 'RUNAWAY'),
#  Text(0, 0, 'LIQUOR LAWS'),
#  Text(0, 0, 'ARSON'),
#  Text(0, 0, 'EMBEZZLEMENT'),
#  Text(0, 0, 'LOITERING'),
#  Text(0, 0, 'SUICIDE'),
#  Text(0, 0, 'FAMILY OFFENSES'),
# ...

# %%
focuscrimes = set(['WEAPON LAWS', 'PROSTITUTION', 'DRIVING UNDER THE INFLUENCE', 'ROBBERY', 'BURGLARY', 'ASSAULT', 'DRUNKENNESS', 'DRUG/NARCOTIC', 'TRESPASS', 'LARCENY/THEFT', 'VANDALISM', 'VEHICLE THEFT', 'STOLEN PROPERTY', 'DISORDERLY CONDUCT'])

# %%
for crime in focuscrimes:
    print(crime)
    police_data[police_data['Category'] == crime].plot(x='Date')
# Out:
# WEAPON LAWS
# PROSTITUTION
# TRESPASS
# VEHICLE THEFT
# STOLEN PROPERTY
# LARCENY/THEFT
# ASSAULT
# DRUG/NARCOTIC
# ROBBERY
# VANDALISM
# DRUNKENNESS
# BURGLARY
# DISORDERLY CONDUCT
# DRIVING UNDER THE INFLUENCE
