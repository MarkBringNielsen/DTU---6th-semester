# %%
from scipy import stats 
import numpy
import urllib.request as request
import csv
import pandas as pd

dataset_1 = 'https://raw.githubusercontent.com/suneman/socialdataanalysis2020/master/files/data1.tsv'
#dataset_2 = 'https://raw.githubusercontent.com/suneman/socialdataanalysis2020/master/files/data2.tsv'
#dataset_3 = 'https://raw.githubusercontent.com/suneman/socialdataanalysis2020/master/files/data3.tsv'
#dataset_4 = 'https://raw.githubusercontent.com/suneman/socialdataanalysis2020/master/files/data4.tsv'

#with request.urlopen(dataset_1) as testfile:
#    dataset_1 = testfile.read().decode()

dataset_1 = pd.DataFrame(request.urlopen(dataset_1), sep='\t', columns=list('XY'))
dataset_1.head()
#dataset_2 = csv.reader(request.urlopen(dataset_2).read().decode, delimiter="\t", quotechar='"')
#dataset_3 = csv.reader(request.urlopen(dataset_3).read(), delimiter="\t", quotechar='"')
#dataset_4 = csv.reader(request.urlopen(dataset_4).read(), delimiter="\t", quotechar='"')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-fe48122247c6> in <module>
#      13 #    dataset_1 = testfile.read().decode()
#      14
# ---> 15 dataset_1 = pd.DataFrame(request.urlopen(dataset_1), sep='\t', columns=list('XY'))
#      16 dataset_1.head()
#      17 #dataset_2 = csv.reader(request.urlopen(dataset_2).read().decode, delimiter="\t", quotechar='"')
#
# TypeError: __init__() got an unexpected keyword argument 'sep'

# %%
print(dataset_1)
for x in dataset_1:
    print(x)
# Out:
# 10	8.04
# 8	6.95
# 13	7.58
# 9	8.81
# 11	8.33
# 14	9.96
# 6	7.24
# 4	4.26
# 12	10.84
# 7	4.82
# 5	5.68
# 1
# 0
#
# 8
# .
# 0
# 4
#
#
# 8
#
# 6
# .
# 9
# 5
#
#
# 1
# 3
#
# 7
# .
# 5
# 8
#
#
# 9
#
# 8
# .
# 8
# 1
#
#
# 1
# 1
#
# 8
# .
# 3
# 3
#
#
# 1
# 4
#
# 9
# .
# 9
# 6
#
#
# 6
#
# 7
# .
# 2
# 4
#
#
# 4
#
# 4
# .
# 2
# 6
#
#
# 1
# 2
#
# 1
# 0
# .
# 8
# 4
#
#
# 7
#
# 4
# .
# 8
# 2
#
#
# 5
#
# 5
# .
# 6
# 8
